# %%
url_data='https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'

# %%
# !wget https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv
# Out:
# --2025-12-26 01:19:01--  https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data.csv’
#
# data.csv                [ <=>                ]   1.62M  --.-KB/s    in 0.1s
#
# 2025-12-26 01:19:01 (12.7 MB/s) - ‘data.csv’ saved [1695423]

# %%
# !cp data.csv ../02-regression-linear/

# %%
# Out:
# linear_algebra.ipynb  numpy-journey.ipynb
